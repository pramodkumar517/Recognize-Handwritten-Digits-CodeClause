# %%
# Import necessary libraries
import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt

# %%
# Load the MNIST dataset (built-in TensorFlow dataset)
mnist = tf.keras.datasets.mnist

# %%
# Split dataset into training and testing data
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
# Normalize the pixel values to a range of 0 to 1 for better performance
x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
# Build the neural network model
model = models.Sequential([
    layers.Flatten(input_shape=(28, 28)),  # Flatten 28x28 images into a 1D vector
    layers.Dense(128, activation='relu'),  # Hidden layer with 128 neurons
    layers.Dropout(0.2),                   # Dropout to prevent overfitting
    layers.Dense(10, activation='softmax')  # Output layer with 10 neurons (one for each digit 0-9)
])

# %%
# Compile the model (define optimizer, loss function, and metrics)
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Train the model with the training data
model.fit(x_train, y_train, epochs=5)

# %%
# Evaluate the model's performance on the test data
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=2)
# Out:
# 313/313 - 0s - 1ms/step - accuracy: 0.9811 - loss: 0.0738

# %%
# Print the test accuracy
print(f'\nTest accuracy: {test_acc}')
# Out:
# Test accuracy: 0.9761000275611877

# %%
# Predict the first test image
predictions = model.predict(x_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
# Visualize the first test image and its predicted label
plt.imshow(x_test[0], cmap='gray')
plt.title(f'Predicted Label: {predictions[0].argmax()}')
plt.show()
